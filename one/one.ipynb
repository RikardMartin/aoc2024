# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
input = pd.read_csv('input.txt', sep='   ', header=None)
input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1000 non-null   int64
#  1   1       1000 non-null   int64
# dtypes: int64(2)
# memory usage: 15.8 KB
# /tmp/ipykernel_5253/2456861717.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   input = pd.read_csv('input.txt', sep='   ', header=None)

# %%
input
# Out:
#          0      1
# 0    39687  54930
# 1    86219  31559
# 2    48536  73145
# 3    19932  82178
# 4    87646  97411
# ..     ...    ...
# 995  83597  72689
# 996  12914  79531
# 997  39621  90125
# 998  10029  95431
# 999  85400  15291
#
# [1000 rows x 2 columns]

# %%
input[0]
# Out:
# 0      39687
# 1      86219
# 2      48536
# 3      19932
# 4      87646
#        ...
# 995    83597
# 996    12914
# 997    39621
# 998    10029
# 999    85400
# Name: 0, Length: 1000, dtype: int64

# %%
left = input[0].sort_values(ascending=True).reset_index()
plt.plot(left.values, marker='.')

# %%
right = input[1].sort_values(ascending=True).reset_index()
plt.plot(right.values, marker='.')

# %%
diff = left[0] - right[1]
diff
# Out:
# 0     -117
# 1     -256
# 2     -468
# 3     -463
# 4     -370
#       ...
# 995   -309
# 996   -110
# 997     48
# 998    150
# 999     29
# Length: 1000, dtype: int64

# %%
diff = diff.abs()
diff
# Out:
# 0      117
# 1      256
# 2      468
# 3      463
# 4      370
#       ...
# 995    309
# 996    110
# 997     48
# 998    150
# 999     29
# Length: 1000, dtype: int64

# %%
diff.sum()
# Out:
# np.int64(1651298)
